# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
random.randint(60, 80)
# Out:
# 68

# %%
list=[]
for i in range(40):
    list.append(random.randint(60, 80))

# %%
list
# Out:
# [67,
#  73,
#  78,
#  61,
#  60,
#  66,
#  61,
#  75,
#  67,
#  66,
#  72,
#  62,
#  64,
#  63,
#  63,
#  62,
#  67,
#  62,
#  75,
#  74,
#  75,
#  72,
#  67,
#  61,
#  77,
#  65,
#  66,
#  70,
#  77,
#  73,
#  72,
#  62,
#  70,
#  73,
#  76,
#  61,
#  60,
#  73,
#  64,
#  76]

# %%
Math_score = [random.randint(60, 80) for _ in range(400)]

# %%
print(Math_score[151])
# Out:
# 72

# %%
Math_score = [random.randint(60, 80) for _ in range(400)]
missing_pct = 0.2  # 20% missing values

# Calculate the number of missing values
n_missing = int(len(Math_score) * missing_pct)

# Generate a list of indices to replace with missing values
missing_indices = random.sample(range(len(Math_score)), n_missing)

# Replace the values at the missing indices with None
for i in missing_indices:
    Math_score[i] = None

# %%
missing_indices
# Out:
# [312,
#  4,
#  56,
#  328,
#  163,
#  219,
#  91,
#  269,
#  221,
#  103,
#  37,
#  83,
#  112,
#  193,
#  99,
#  389,
#  282,
#  121,
#  252,
#  194,
#  270,
#  276,
#  330,
#  243,
#  359,
#  78,
#  16,
#  313,
#  242,
#  1,
#  98,
#  286,
#  134,
#  215,
#  380,
#  213,
#  278,
#  127,
#  293,
#  65,
#  3,
#  17,
#  275,
#  268,
#  307,
#  81,
#  155,
#  130,
#  238,
#  106,
#  181,
#  140,
#  48,
#  156,
#  94,
#  58,
#  211,
#  331,
#  171,
#  227,
#  369,
#  290,
#  52,
#  260,
#  372,
#  88,
#  145,
#  280,
#  18,
#  79,
#  147,
#  85,
#  46,
#  383,
#  45,
#  173,
#  355,
#  183,
#  208,
#  68]

# %%
Math_score
# Out:
# [71,
#  None,
#  69,
#  None,
#  None,
#  64,
#  65,
#  62,
#  70,
#  68,
#  76,
#  75,
#  67,
#  75,
#  68,
#  74,
#  None,
#  None,
#  None,
#  72,
#  68,
#  71,
#  61,
#  62,
#  77,
#  64,
#  78,
#  64,
#  71,
#  74,
#  72,
#  62,
#  63,
#  77,
#  80,
#  61,
#  75,
#  None,
#  68,
#  72,
#  70,
#  63,
#  76,
#  73,
#  78,
#  None,
#  None,
#  72,
#  None,
#  64,
#  80,
#  77,
#  None,
#  64,
#  62,
#  66,
#  None,
#  63,
#  None,
#  76,
#  62,
#  60,
#  69,
#  76,
#  64,
#  None,
#  72,
#  63,
#  None,
#  76,
#  65,
#  68,
#  76,
#  72,
#  79,
#  80,
#  64,
#  80,
#  None,
#  None,
#  79,
#  None,
#  80,
#  None,
#  66,
#  None,
#  79,
#  67,
#  None,
#  77,
#  79,
#  None,
#  65,
#  73,
#  None,
#  61,
#  62,
#  63,
#  None,
#  None,
#  69,
#  61,
#  74,
#  None,
#  78,
#  62,
#  None,
#  80,
#  77,
#  73,
#  80,
#  61,
#  None,
#  68,
#  75,
#  68,
#  62,
#  76,
#  64,
#  68,
#  70,
#  None,
#  72,
#  73,
#  74,
#  71,
#  80,
#  None,
#  67,
#  67,
#  None,
#  78,
#  73,
#  61,
#  None,
#  69,
#  65,
#  79,
#  60,
#  65,
#  None,
#  65,
#  74,
#  60,
#  68,
#  None,
#  78,
#  None,
#  60,
#  67,
#  74,
#  60,
#  67,
#  63,
#  73,
#  None,
#  None,
#  79,
#  73,
#  75,
#  60,
#  77,
#  76,
#  None,
#  78,
#  66,
#  76,
#  70,
#  76,
#  63,
#  70,
#  None,
#  65,
#  None,
#  61,
#  61,
#  76,
#  61,
#  77,
#  70,
#  76,
#  None,
#  78,
#  None,
#  76,
#  69,
#  78,
#  60,
#  69,
#  60,
#  60,
#  63,
#  80,
#  None,
#  None,
#  78,
#  80,
#  67,
#  68,
#  65,
#  63,
#  61,
#  71,
#  62,
#  74,
#  61,
#  75,
#  76,
#  None,
#  64,
#  71,
#  None,
#  71,
#  None,
#  72,
#  None,
#  79,
#  68,
#  66,
#  None,
#  78,
#  None,
#  67,
#  76,
#  68,
#  61,
#  75,
#  None,
#  61,
#  80,
#  70,
#  61,
#  77,
#  69,
#  64,
#  69,
#  79,
#  66,
#  None,
#  76,
#  66,
#  68,
#  None,
#  None,
#  68,
#  74,
#  60,
#  60,
#  73,
#  72,
#  74,
#  65,
#  None,
#  60,
#  68,
#  73,
#  79,
#  80,
#  72,
#  77,
#  None,
#  71,
#  74,
#  67,
#  70,
#  60,
#  72,
#  77,
#  None,
#  None,
#  None,
#  73,
#  68,
#  60,
#  64,
#  None,
#  None,
#  72,
#  None,
#  75,
#  None,
#  74,
#  None,
#  69,
#  79,
#  63,
#  None,
#  76,
#  64,
#  73,
#  None,
#  72,
#  71,
#  None,
#  71,
#  71,
#  68,
#  66,
#  76,
#  65,
#  72,
#  63,
#  73,
#  63,
#  78,
#  74,
#  65,
#  None,
#  80,
#  79,
#  79,
#  73,
#  None,
#  None,
#  63,
#  67,
#  66,
#  78,
#  71,
#  72,
#  78,
#  73,
#  65,
#  67,
#  74,
#  71,
#  71,
#  62,
#  None,
#  74,
#  None,
#  None,
#  73,
#  65,
#  69,
#  60,
#  67,
#  60,
#  77,
#  77,
#  66,
#  80,
#  71,
#  63,
#  65,
#  74,
#  72,
#  65,
#  79,
#  65,
#  79,
#  62,
#  70,
#  79,
#  79,
#  None,
#  72,
#  73,
#  63,
#  None,
#  69,
#  73,
#  77,
#  61,
#  71,
#  67,
#  67,
#  67,
#  68,
#  None,
#  71,
#  68,
#  None,
#  71,
#  61,
#  79,
#  78,
#  69,
#  72,
#  77,
#  None,
#  73,
#  74,
#  None,
#  76,
#  61,
#  79,
#  63,
#  69,
#  None,
#  76,
#  77,
#  71,
#  61,
#  67,
#  73,
#  72,
#  76,
#  68,
#  64]

# %%
Reading_score = [random.randint(75, 95) for _ in range(400)]
missing_pct = 0.1  # 10% missing values

# Calculate the number of missing values
n_missing = int(len(Reading_score) * missing_pct)

# Generate a list of indices to replace with missing values
missing_indices = random.sample(range(len(Reading_score)), n_missing)

# Replace the values at the missing indices with None
for i in missing_indices:
    Reading_score[i] = None

# %%
Reading_score
# Out:
# [81,
#  79,
#  77,
#  92,
#  94,
#  90,
#  85,
#  80,
#  85,
#  85,
#  91,
#  88,
#  88,
#  79,
#  89,
#  75,
#  91,
#  91,
#  95,
#  85,
#  84,
#  93,
#  84,
#  75,
#  94,
#  79,
#  77,
#  87,
#  77,
#  93,
#  None,
#  82,
#  88,
#  95,
#  87,
#  86,
#  None,
#  89,
#  93,
#  88,
#  78,
#  95,
#  77,
#  None,
#  90,
#  None,
#  85,
#  82,
#  91,
#  79,
#  82,
#  79,
#  84,
#  88,
#  84,
#  83,
#  92,
#  80,
#  75,
#  90,
#  80,
#  76,
#  75,
#  None,
#  76,
#  86,
#  79,
#  89,
#  77,
#  75,
#  78,
#  84,
#  88,
#  None,
#  89,
#  93,
#  82,
#  None,
#  82,
#  78,
#  92,
#  92,
#  95,
#  None,
#  94,
#  78,
#  81,
#  86,
#  88,
#  78,
#  75,
#  83,
#  81,
#  86,
#  84,
#  87,
#  77,
#  80,
#  86,
#  95,
#  95,
#  None,
#  75,
#  84,
#  78,
#  87,
#  95,
#  79,
#  76,
#  None,
#  90,
#  93,
#  82,
#  93,
#  88,
#  76,
#  90,
#  91,
#  90,
#  92,
#  81,
#  90,
#  86,
#  76,
#  78,
#  76,
#  82,
#  80,
#  77,
#  None,
#  None,
#  84,
#  91,
#  82,
#  79,
#  83,
#  None,
#  92,
#  87,
#  78,
#  82,
#  83,
#  90,
#  92,
#  84,
#  88,
#  92,
#  89,
#  87,
#  84,
#  86,
#  None,
#  88,
#  81,
#  89,
#  90,
#  84,
#  77,
#  None,
#  95,
#  78,
#  89,
#  94,
#  89,
#  None,
#  75,
#  90,
#  78,
#  None,
#  None,
#  None,
#  80,
#  86,
#  None,
#  75,
#  75,
#  86,
#  83,
#  85,
#  80,
#  79,
#  87,
#  93,
#  75,
#  88,
#  80,
#  75,
#  89,
#  94,
#  87,
#  84,
#  91,
#  90,
#  85,
#  86,
#  94,
#  85,
#  75,
#  95,
#  85,
#  94,
#  89,
#  79,
#  None,
#  90,
#  90,
#  94,
#  76,
#  91,
#  87,
#  87,
#  None,
#  93,
#  None,
#  90,
#  93,
#  87,
#  80,
#  88,
#  80,
#  78,
#  95,
#  89,
#  90,
#  88,
#  86,
#  None,
#  94,
#  81,
#  None,
#  95,
#  None,
#  95,
#  95,
#  92,
#  94,
#  88,
#  81,
#  92,
#  86,
#  80,
#  89,
#  91,
#  91,
#  88,
#  87,
#  77,
#  80,
#  87,
#  93,
#  88,
#  78,
#  75,
#  77,
#  77,
#  86,
#  93,
#  88,
#  75,
#  87,
#  85,
#  76,
#  81,
#  84,
#  80,
#  91,
#  85,
#  88,
#  90,
#  85,
#  94,
#  87,
#  92,
#  90,
#  82,
#  81,
#  83,
#  88,
#  None,
#  85,
#  78,
#  78,
#  93,
#  93,
#  95,
#  89,
#  89,
#  76,
#  90,
#  85,
#  84,
#  87,
#  88,
#  78,
#  84,
#  84,
#  77,
#  None,
#  80,
#  87,
#  83,
#  None,
#  80,
#  80,
#  81,
#  84,
#  82,
#  89,
#  85,
#  None,
#  None,
#  87,
#  76,
#  None,
#  91,
#  84,
#  94,
#  80,
#  92,
#  82,
#  75,
#  94,
#  76,
#  80,
#  82,
#  79,
#  82,
#  78,
#  94,
#  86,
#  91,
#  79,
#  86,
#  78,
#  94,
#  75,
#  93,
#  95,
#  83,
#  None,
#  None,
#  83,
#  93,
#  89,
#  88,
#  None,
#  93,
#  77,
#  92,
#  85,
#  83,
#  93,
#  75,
#  None,
#  90,
#  92,
#  86,
#  79,
#  84,
#  91,
#  83,
#  76,
#  94,
#  92,
#  86,
#  85,
#  None,
#  None,
#  77,
#  82,
#  92,
#  84,
#  84,
#  93,
#  78,
#  79,
#  91,
#  None,
#  75,
#  79,
#  95,
#  79,
#  None,
#  78,
#  79,
#  91,
#  77,
#  84,
#  87,
#  75,
#  81,
#  80,
#  85,
#  89,
#  93,
#  79,
#  95,
#  90,
#  85,
#  83]

# %%
Writing_score = [random.randint(60, 80) for _ in range(400)]

# %%
Writing_score
# Out:
# [66,
#  60,
#  76,
#  66,
#  76,
#  74,
#  66,
#  79,
#  72,
#  76,
#  80,
#  80,
#  79,
#  74,
#  65,
#  68,
#  69,
#  62,
#  62,
#  73,
#  80,
#  78,
#  73,
#  63,
#  73,
#  69,
#  69,
#  66,
#  78,
#  69,
#  68,
#  66,
#  72,
#  70,
#  71,
#  80,
#  63,
#  77,
#  62,
#  74,
#  67,
#  78,
#  72,
#  63,
#  74,
#  78,
#  66,
#  69,
#  69,
#  75,
#  62,
#  60,
#  80,
#  70,
#  63,
#  80,
#  73,
#  79,
#  60,
#  71,
#  70,
#  60,
#  66,
#  79,
#  80,
#  64,
#  63,
#  63,
#  63,
#  67,
#  71,
#  68,
#  63,
#  60,
#  64,
#  77,
#  68,
#  75,
#  67,
#  77,
#  73,
#  65,
#  74,
#  70,
#  69,
#  77,
#  61,
#  66,
#  65,
#  70,
#  77,
#  60,
#  60,
#  76,
#  75,
#  69,
#  74,
#  71,
#  64,
#  62,
#  68,
#  73,
#  80,
#  70,
#  69,
#  78,
#  71,
#  78,
#  70,
#  79,
#  63,
#  72,
#  63,
#  67,
#  77,
#  79,
#  79,
#  64,
#  74,
#  79,
#  76,
#  63,
#  73,
#  69,
#  60,
#  71,
#  78,
#  65,
#  69,
#  79,
#  74,
#  71,
#  76,
#  61,
#  74,
#  63,
#  65,
#  71,
#  77,
#  75,
#  71,
#  63,
#  78,
#  71,
#  61,
#  75,
#  64,
#  67,
#  68,
#  60,
#  63,
#  66,
#  72,
#  72,
#  67,
#  62,
#  62,
#  60,
#  63,
#  69,
#  80,
#  72,
#  80,
#  64,
#  64,
#  69,
#  63,
#  62,
#  64,
#  78,
#  62,
#  61,
#  70,
#  64,
#  78,
#  60,
#  77,
#  62,
#  76,
#  76,
#  74,
#  63,
#  65,
#  75,
#  72,
#  67,
#  63,
#  80,
#  68,
#  71,
#  61,
#  71,
#  72,
#  67,
#  65,
#  68,
#  69,
#  73,
#  67,
#  71,
#  74,
#  61,
#  61,
#  68,
#  73,
#  77,
#  74,
#  75,
#  68,
#  71,
#  67,
#  68,
#  71,
#  77,
#  67,
#  71,
#  70,
#  75,
#  70,
#  67,
#  62,
#  71,
#  71,
#  62,
#  72,
#  68,
#  71,
#  77,
#  77,
#  75,
#  67,
#  75,
#  78,
#  68,
#  63,
#  74,
#  60,
#  68,
#  65,
#  65,
#  76,
#  68,
#  63,
#  78,
#  80,
#  75,
#  67,
#  62,
#  76,
#  62,
#  73,
#  72,
#  77,
#  75,
#  70,
#  74,
#  77,
#  78,
#  68,
#  61,
#  71,
#  76,
#  78,
#  76,
#  79,
#  71,
#  70,
#  79,
#  77,
#  67,
#  74,
#  62,
#  64,
#  78,
#  61,
#  71,
#  78,
#  75,
#  61,
#  69,
#  75,
#  79,
#  67,
#  78,
#  74,
#  66,
#  64,
#  77,
#  74,
#  64,
#  64,
#  68,
#  70,
#  67,
#  79,
#  62,
#  64,
#  70,
#  73,
#  69,
#  71,
#  77,
#  66,
#  80,
#  74,
#  76,
#  72,
#  80,
#  77,
#  73,
#  74,
#  76,
#  79,
#  63,
#  63,
#  64,
#  65,
#  69,
#  65,
#  78,
#  66,
#  74,
#  70,
#  78,
#  66,
#  76,
#  70,
#  65,
#  75,
#  71,
#  68,
#  67,
#  71,
#  68,
#  60,
#  72,
#  79,
#  66,
#  64,
#  60,
#  75,
#  66,
#  79,
#  80,
#  79,
#  76,
#  65,
#  61,
#  68,
#  69,
#  75,
#  67,
#  72,
#  73,
#  67,
#  67,
#  64,
#  61,
#  74,
#  65,
#  75,
#  76,
#  63,
#  73,
#  78,
#  74,
#  67,
#  77,
#  76,
#  77,
#  69,
#  66,
#  64,
#  70,
#  61,
#  61,
#  70,
#  72,
#  79,
#  65,
#  68,
#  67,
#  70,
#  67,
#  78,
#  76,
#  78,
#  78,
#  73,
#  70,
#  73,
#  61,
#  63,
#  65,
#  66,
#  60,
#  74,
#  79,
#  80,
#  80]

# %%
Placement_score = [random.randint(75, 100) for _ in range(400)]

# %%
Placement_score
# Out:
# [80,
#  80,
#  98,
#  100,
#  87,
#  88,
#  90,
#  82,
#  96,
#  97,
#  85,
#  80,
#  88,
#  94,
#  81,
#  100,
#  79,
#  82,
#  76,
#  77,
#  95,
#  94,
#  79,
#  91,
#  91,
#  82,
#  90,
#  82,
#  85,
#  82,
#  88,
#  89,
#  82,
#  81,
#  83,
#  100,
#  98,
#  92,
#  89,
#  95,
#  75,
#  82,
#  91,
#  75,
#  84,
#  85,
#  96,
#  94,
#  85,
#  100,
#  79,
#  77,
#  82,
#  100,
#  91,
#  79,
#  77,
#  91,
#  98,
#  85,
#  87,
#  78,
#  76,
#  97,
#  94,
#  78,
#  96,
#  82,
#  93,
#  95,
#  98,
#  97,
#  81,
#  86,
#  92,
#  99,
#  85,
#  99,
#  78,
#  98,
#  82,
#  83,
#  94,
#  95,
#  76,
#  99,
#  100,
#  80,
#  89,
#  88,
#  89,
#  94,
#  76,
#  95,
#  78,
#  100,
#  99,
#  92,
#  87,
#  96,
#  96,
#  78,
#  96,
#  91,
#  94,
#  86,
#  84,
#  83,
#  94,
#  77,
#  79,
#  82,
#  88,
#  90,
#  83,
#  92,
#  90,
#  79,
#  90,
#  98,
#  97,
#  99,
#  76,
#  97,
#  87,
#  75,
#  85,
#  86,
#  99,
#  86,
#  79,
#  94,
#  77,
#  81,
#  97,
#  79,
#  75,
#  95,
#  98,
#  93,
#  75,
#  75,
#  82,
#  100,
#  96,
#  98,
#  99,
#  81,
#  91,
#  87,
#  82,
#  79,
#  100,
#  87,
#  94,
#  98,
#  79,
#  84,
#  79,
#  85,
#  100,
#  78,
#  87,
#  75,
#  81,
#  94,
#  97,
#  83,
#  96,
#  94,
#  88,
#  78,
#  83,
#  89,
#  96,
#  80,
#  85,
#  87,
#  82,
#  94,
#  96,
#  81,
#  93,
#  89,
#  88,
#  77,
#  75,
#  80,
#  92,
#  84,
#  91,
#  89,
#  99,
#  87,
#  97,
#  76,
#  76,
#  84,
#  78,
#  92,
#  97,
#  95,
#  99,
#  89,
#  99,
#  75,
#  83,
#  76,
#  85,
#  76,
#  95,
#  81,
#  98,
#  85,
#  83,
#  95,
#  100,
#  94,
#  89,
#  86,
#  87,
#  82,
#  75,
#  93,
#  96,
#  82,
#  93,
#  81,
#  89,
#  95,
#  75,
#  97,
#  100,
#  92,
#  79,
#  94,
#  84,
#  82,
#  84,
#  85,
#  97,
#  89,
#  83,
#  84,
#  86,
#  79,
#  78,
#  100,
#  94,
#  98,
#  100,
#  86,
#  91,
#  82,
#  79,
#  95,
#  94,
#  88,
#  83,
#  78,
#  94,
#  85,
#  89,
#  90,
#  83,
#  87,
#  80,
#  87,
#  97,
#  82,
#  84,
#  91,
#  78,
#  88,
#  99,
#  79,
#  77,
#  78,
#  83,
#  82,
#  77,
#  87,
#  90,
#  91,
#  79,
#  94,
#  78,
#  99,
#  100,
#  98,
#  85,
#  81,
#  93,
#  99,
#  76,
#  85,
#  96,
#  81,
#  76,
#  97,
#  92,
#  85,
#  100,
#  78,
#  88,
#  82,
#  94,
#  97,
#  100,
#  88,
#  90,
#  95,
#  93,
#  92,
#  84,
#  76,
#  91,
#  85,
#  75,
#  95,
#  81,
#  90,
#  85,
#  79,
#  89,
#  81,
#  80,
#  93,
#  84,
#  98,
#  95,
#  86,
#  77,
#  76,
#  100,
#  82,
#  77,
#  83,
#  99,
#  78,
#  81,
#  87,
#  91,
#  87,
#  93,
#  98,
#  85,
#  79,
#  82,
#  89,
#  86,
#  88,
#  78,
#  95,
#  96,
#  88,
#  75,
#  79,
#  78,
#  79,
#  84,
#  81,
#  92,
#  79,
#  99,
#  92,
#  75,
#  81,
#  95,
#  82,
#  80,
#  77,
#  86,
#  94,
#  90,
#  77,
#  89,
#  85,
#  93,
#  98,
#  90,
#  82,
#  83,
#  81,
#  78,
#  77,
#  82,
#  78,
#  98,
#  96,
#  80,
#  85,
#  78,
#  94,
#  75,
#  76,
#  84,
#  85,
#  75,
#  95]

# %%
Club_list = ['2018', '2019','2020', '2021']
Club_Join_Date= [random.choice(Club_list) for _ in range(400)]

# %%
Club_Join_Date
# Out:
# ['2021',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2020',
#  '2019',
#  '2018',
#  '2021',
#  '2018',
#  '2021',
#  '2019',
#  '2020',
#  '2019',
#  '2020',
#  '2019',
#  '2021',
#  '2018',
#  '2019',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2018',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2019',
#  '2018',
#  '2019',
#  '2018',
#  '2021',
#  '2019',
#  '2019',
#  '2018',
#  '2020',
#  '2018',
#  '2020',
#  '2020',
#  '2019',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2020',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2019',
#  '2021',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2020',
#  '2018',
#  '2021',
#  '2018',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2021',
#  '2019',
#  '2018',
#  '2021',
#  '2021',
#  '2018',
#  '2019',
#  '2018',
#  '2020',
#  '2021',
#  '2020',
#  '2018',
#  '2021',
#  '2021',
#  '2019',
#  '2020',
#  '2018',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2020',
#  '2020',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2019',
#  '2020',
#  '2021',
#  '2020',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2019',
#  '2021',
#  '2019',
#  '2020',
#  '2018',
#  '2019',
#  '2018',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2020',
#  '2020',
#  '2018',
#  '2020',
#  '2018',
#  '2020',
#  '2018',
#  '2020',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2019',
#  '2021',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2018',
#  '2018',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2021',
#  '2021',
#  '2018',
#  '2020',
#  '2021',
#  '2019',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2020',
#  '2018',
#  '2019',
#  '2018',
#  '2020',
#  '2021',
#  '2020',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2019',
#  '2019',
#  '2018',
#  '2020',
#  '2021',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2019',
#  '2019',
#  '2018',
#  '2020',
#  '2019',
#  '2020',
#  '2020',
#  '2021',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2018',
#  '2021',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2021',
#  '2018',
#  '2018',
#  '2019',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2021',
#  '2020',
#  '2020',
#  '2018',
#  '2018',
#  '2019',
#  '2018',
#  '2020',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2021',
#  '2021',
#  '2018',
#  '2021',
#  '2019',
#  '2020',
#  '2021',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2019',
#  '2018',
#  '2021',
#  '2018',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2018',
#  '2020',
#  '2019',
#  '2021',
#  '2019',
#  '2021',
#  '2019',
#  '2019',
#  '2018',
#  '2021',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2018',
#  '2020',
#  '2020',
#  '2018',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2021',
#  '2019',
#  '2018',
#  '2019',
#  '2018',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2019',
#  '2020',
#  '2020',
#  '2018',
#  '2021',
#  '2020',
#  '2021']

# %%
df = {}

df["Math_score"] = Math_score
df['Reading_score'] = Reading_score
df["Writing_score"] = Writing_score
df["Placement_score"] =Placement_score
df["Club_Join_Date"] = Club_Join_Date

# %%
df
# Out:
# {'Math_score': [71,
#   None,
#   69,
#   None,
#   None,
#   64,
#   65,
#   62,
#   70,
#   68,
#   76,
#   75,
#   67,
#   75,
#   68,
#   74,
#   None,
#   None,
#   None,
#   72,
#   68,
#   71,
#   61,
#   62,
#   77,
#   64,
#   78,
#   64,
#   71,
#   74,
#   72,
#   62,
#   63,
#   77,
#   80,
#   61,
#   75,
#   None,
#   68,
#   72,
#   70,
#   63,
#   76,
#   73,
#   78,
#   None,
#   None,
#   72,
#   None,
#   64,
#   80,
#   77,
#   None,
#   64,
#   62,
#   66,
#   None,
#   63,
#   None,
#   76,
#   62,
#   60,
#   69,
#   76,
#   64,
#   None,
#   72,
#   63,
#   None,
#   76,
#   65,
#   68,
#   76,
#   72,
#   79,
#   80,
#   64,
#   80,
#   None,
#   None,
#   79,
#   None,
#   80,
#   None,
#   66,
#   None,
#   79,
#   67,
#   None,
#   77,
#   79,
#   None,
#   65,
#   73,
#   None,
#   61,
#   62,
#   63,
#   None,
#   None,
#   69,
#   61,
#   74,
#   None,
#   78,
#   62,
#   None,
#   80,
#   77,
#   73,
#   80,
#   61,
#   None,
#   68,
#   75,
#   68,
#   62,
#   76,
#   64,
#   68,
#   70,
#   None,
#   72,
#   73,
#   74,
#   71,
#   80,
#   None,
#   67,
#   67,
#   None,
#   78,
#   73,
#   61,
#   None,
#   69,
#   65,
#   79,
#   60,
#   65,
#   None,
#   65,
#   74,
#   60,
#   68,
#   None,
#   78,
#   None,
#   60,
#   67,
#   74,
#   60,
#   67,
#   63,
#   73,
#   None,
#   None,
#   79,
#   73,
#   75,
#   60,
#   77,
#   76,
#   None,
#   78,
#   66,
#   76,
#   70,
#   76,
#   63,
#   70,
#   None,
#   65,
#   None,
#   61,
#   61,
#   76,
#   61,
#   77,
#   70,
#   76,
#   None,
#   78,
#   None,
#   76,
#   69,
#   78,
#   60,
#   69,
#   60,
#   60,
#   63,
#   80,
#   None,
#   None,
#   78,
#   80,
#   67,
#   68,
#   65,
#   63,
#   61,
#   71,
#   62,
#   74,
#   61,
#   75,
#   76,
#   None,
#   64,
#   71,
#   None,
#   71,
#   None,
#   72,
#   None,
#   79,
#   68,
#   66,
#   None,
#   78,
#   None,
#   67,
#   76,
#   68,
#   61,
#   75,
#   None,
#   61,
#   80,
#   70,
#   61,
#   77,
#   69,
#   64,
#   69,
#   79,
#   66,
#   None,
#   76,
#   66,
#   68,
#   None,
#   None,
#   68,
#   74,
#   60,
#   60,
#   73,
#   72,
#   74,
#   65,
#   None,
#   60,
#   68,
#   73,
#   79,
#   80,
#   72,
#   77,
#   None,
#   71,
#   74,
#   67,
#   70,
#   60,
#   72,
#   77,
#   None,
#   None,
#   None,
#   73,
#   68,
#   60,
#   64,
#   None,
#   None,
#   72,
#   None,
#   75,
#   None,
#   74,
#   None,
#   69,
#   79,
#   63,
#   None,
#   76,
#   64,
#   73,
#   None,
#   72,
#   71,
#   None,
#   71,
#   71,
#   68,
#   66,
#   76,
#   65,
#   72,
#   63,
#   73,
#   63,
#   78,
#   74,
#   65,
#   None,
#   80,
#   79,
#   79,
#   73,
#   None,
#   None,
#   63,
#   67,
#   66,
#   78,
#   71,
#   72,
#   78,
#   73,
#   65,
#   67,
#   74,
#   71,
#   71,
#   62,
#   None,
#   74,
#   None,
#   None,
#   73,
#   65,
#   69,
#   60,
#   67,
#   60,
#   77,
#   77,
#   66,
#   80,
#   71,
#   63,
#   65,
#   74,
#   72,
#   65,
#   79,
#   65,
#   79,
#   62,
#   70,
#   79,
#   79,
#   None,
#   72,
#   73,
#   63,
#   None,
#   69,
#   73,
#   77,
#   61,
#   71,
#   67,
#   67,
#   67,
#   68,
#   None,
#   71,
#   68,
#   None,
#   71,
#   61,
#   79,
#   78,
#   69,
#   72,
#   77,
#   None,
#   73,
#   74,
#   None,
#   76,
#   61,
#   79,
#   63,
#   69,
#   None,
#   76,
#   77,
#   71,
#   61,
#   67,
#   73,
#   72,
#   76,
#   68,
#   64],
#  'Reading_score': [81,
#   79,
#   77,
#   92,
#   94,
#   90,
#   85,
#   80,
#   85,
#   85,
#   91,
#   88,
#   88,
#   79,
#   89,
#   75,
#   91,
#   91,
#   95,
#   85,
#   84,
#   93,
#   84,
#   75,
#   94,
#   79,
#   77,
#   87,
#   77,
#   93,
#   None,
#   82,
#   88,
#   95,
#   87,
#   86,
#   None,
#   89,
#   93,
#   88,
#   78,
#   95,
#   77,
#   None,
#   90,
#   None,
#   85,
#   82,
#   91,
#   79,
#   82,
#   79,
#   84,
#   88,
#   84,
#   83,
#   92,
#   80,
#   75,
#   90,
#   80,
#   76,
#   75,
#   None,
#   76,
#   86,
#   79,
#   89,
#   77,
#   75,
#   78,
#   84,
#   88,
#   None,
#   89,
#   93,
#   82,
#   None,
#   82,
#   78,
#   92,
#   92,
#   95,
#   None,
#   94,
#   78,
#   81,
#   86,
#   88,
#   78,
#   75,
#   83,
#   81,
#   86,
#   84,
#   87,
#   77,
#   80,
#   86,
#   95,
#   95,
#   None,
#   75,
#   84,
#   78,
#   87,
#   95,
#   79,
#   76,
#   None,
#   90,
#   93,
#   82,
#   93,
#   88,
#   76,
#   90,
#   91,
#   90,
#   92,
#   81,
#   90,
#   86,
#   76,
#   78,
#   76,
#   82,
#   80,
#   77,
#   None,
#   None,
#   84,
#   91,
#   82,
#   79,
#   83,
#   None,
#   92,
#   87,
#   78,
#   82,
#   83,
#   90,
#   92,
#   84,
#   88,
#   92,
#   89,
#   87,
#   84,
#   86,
#   None,
#   88,
#   81,
#   89,
#   90,
#   84,
#   77,
#   None,
#   95,
#   78,
#   89,
#   94,
#   89,
#   None,
#   75,
#   90,
#   78,
#   None,
#   None,
#   None,
#   80,
#   86,
#   None,
#   75,
#   75,
#   86,
#   83,
#   85,
#   80,
#   79,
#   87,
#   93,
#   75,
#   88,
#   80,
#   75,
#   89,
#   94,
#   87,
#   84,
#   91,
#   90,
#   85,
#   86,
#   94,
#   85,
#   75,
#   95,
#   85,
#   94,
#   89,
#   79,
#   None,
#   90,
#   90,
#   94,
#   76,
#   91,
#   87,
#   87,
#   None,
#   93,
#   None,
#   90,
#   93,
#   87,
#   80,
#   88,
#   80,
#   78,
#   95,
#   89,
#   90,
#   88,
#   86,
#   None,
#   94,
#   81,
#   None,
#   95,
#   None,
#   95,
#   95,
#   92,
#   94,
#   88,
#   81,
#   92,
#   86,
#   80,
#   89,
#   91,
#   91,
#   88,
#   87,
#   77,
#   80,
#   87,
#   93,
#   88,
#   78,
#   75,
#   77,
#   77,
#   86,
#   93,
#   88,
#   75,
#   87,
#   85,
#   76,
#   81,
#   84,
#   80,
#   91,
#   85,
#   88,
#   90,
#   85,
#   94,
#   87,
#   92,
#   90,
#   82,
#   81,
#   83,
#   88,
#   None,
#   85,
#   78,
#   78,
#   93,
#   93,
#   95,
#   89,
#   89,
#   76,
#   90,
#   85,
#   84,
#   87,
#   88,
#   78,
#   84,
#   84,
#   77,
#   None,
#   80,
#   87,
#   83,
#   None,
#   80,
#   80,
#   81,
#   84,
#   82,
#   89,
#   85,
#   None,
#   None,
#   87,
#   76,
#   None,
#   91,
#   84,
#   94,
#   80,
#   92,
#   82,
#   75,
#   94,
#   76,
#   80,
#   82,
#   79,
#   82,
#   78,
#   94,
#   86,
#   91,
#   79,
#   86,
#   78,
#   94,
#   75,
#   93,
#   95,
#   83,
#   None,
#   None,
#   83,
#   93,
#   89,
#   88,
#   None,
#   93,
#   77,
#   92,
#   85,
#   83,
#   93,
#   75,
#   None,
#   90,
#   92,
#   86,
#   79,
#   84,
#   91,
#   83,
#   76,
#   94,
#   92,
#   86,
#   85,
#   None,
#   None,
#   77,
#   82,
#   92,
#   84,
#   84,
#   93,
#   78,
#   79,
#   91,
#   None,
#   75,
#   79,
#   95,
#   79,
#   None,
#   78,
#   79,
#   91,
#   77,
#   84,
#   87,
#   75,
#   81,
#   80,
#   85,
#   89,
#   93,
#   79,
#   95,
#   90,
#   85,
#   83],
#  'Writing_score': [66,
#   60,
#   76,
#   66,
#   76,
#   74,
#   66,
#   79,
#   72,
#   76,
#   80,
#   80,
#   79,
#   74,
#   65,
#   68,
#   69,
#   62,
#   62,
#   73,
#   80,
#   78,
#   73,
#   63,
#   73,
#   69,
#   69,
#   66,
#   78,
#   69,
#   68,
#   66,
#   72,
#   70,
#   71,
#   80,
#   63,
#   77,
#   62,
#   74,
#   67,
#   78,
#   72,
#   63,
#   74,
#   78,
#   66,
#   69,
#   69,
#   75,
#   62,
#   60,
#   80,
#   70,
#   63,
#   80,
#   73,
#   79,
#   60,
#   71,
#   70,
#   60,
#   66,
#   79,
#   80,
#   64,
#   63,
#   63,
#   63,
#   67,
#   71,
#   68,
#   63,
#   60,
#   64,
#   77,
#   68,
#   75,
#   67,
#   77,
#   73,
#   65,
#   74,
#   70,
#   69,
#   77,
#   61,
#   66,
#   65,
#   70,
#   77,
#   60,
#   60,
#   76,
#   75,
#   69,
#   74,
#   71,
#   64,
#   62,
#   68,
#   73,
#   80,
#   70,
#   69,
#   78,
#   71,
#   78,
#   70,
#   79,
#   63,
#   72,
#   63,
#   67,
#   77,
#   79,
#   79,
#   64,
#   74,
#   79,
#   76,
#   63,
#   73,
#   69,
#   60,
#   71,
#   78,
#   65,
#   69,
#   79,
#   74,
#   71,
#   76,
#   61,
#   74,
#   63,
#   65,
#   71,
#   77,
#   75,
#   71,
#   63,
#   78,
#   71,
#   61,
#   75,
#   64,
#   67,
#   68,
#   60,
#   63,
#   66,
#   72,
#   72,
#   67,
#   62,
#   62,
#   60,
#   63,
#   69,
#   80,
#   72,
#   80,
#   64,
#   64,
#   69,
#   63,
#   62,
#   64,
#   78,
#   62,
#   61,
#   70,
#   64,
#   78,
#   60,
#   77,
#   62,
#   76,
#   76,
#   74,
#   63,
#   65,
#   75,
#   72,
#   67,
#   63,
#   80,
#   68,
#   71,
#   61,
#   71,
#   72,
#   67,
#   65,
#   68,
#   69,
#   73,
#   67,
#   71,
#   74,
#   61,
#   61,
#   68,
#   73,
#   77,
#   74,
#   75,
#   68,
#   71,
#   67,
#   68,
#   71,
#   77,
#   67,
#   71,
#   70,
#   75,
#   70,
#   67,
#   62,
#   71,
#   71,
#   62,
#   72,
#   68,
#   71,
#   77,
#   77,
#   75,
#   67,
#   75,
#   78,
#   68,
#   63,
#   74,
#   60,
#   68,
#   65,
#   65,
#   76,
#   68,
#   63,
#   78,
#   80,
#   75,
#   67,
#   62,
#   76,
#   62,
#   73,
#   72,
#   77,
#   75,
#   70,
#   74,
#   77,
#   78,
#   68,
#   61,
#   71,
#   76,
#   78,
#   76,
#   79,
#   71,
#   70,
#   79,
#   77,
#   67,
#   74,
#   62,
#   64,
#   78,
#   61,
#   71,
#   78,
#   75,
#   61,
#   69,
#   75,
#   79,
#   67,
#   78,
#   74,
#   66,
#   64,
#   77,
#   74,
#   64,
#   64,
#   68,
#   70,
#   67,
#   79,
#   62,
#   64,
#   70,
#   73,
#   69,
#   71,
#   77,
#   66,
#   80,
#   74,
#   76,
#   72,
#   80,
#   77,
#   73,
#   74,
#   76,
#   79,
#   63,
#   63,
#   64,
#   65,
#   69,
#   65,
#   78,
#   66,
#   74,
#   70,
#   78,
#   66,
#   76,
#   70,
#   65,
#   75,
#   71,
#   68,
#   67,
#   71,
#   68,
#   60,
#   72,
#   79,
#   66,
#   64,
#   60,
#   75,
#   66,
#   79,
#   80,
#   79,
#   76,
#   65,
#   61,
#   68,
#   69,
#   75,
#   67,
#   72,
#   73,
#   67,
#   67,
#   64,
#   61,
#   74,
#   65,
#   75,
#   76,
#   63,
#   73,
#   78,
#   74,
#   67,
#   77,
#   76,
#   77,
#   69,
#   66,
#   64,
#   70,
#   61,
#   61,
#   70,
#   72,
#   79,
#   65,
#   68,
#   67,
#   70,
#   67,
#   78,
#   76,
#   78,
#   78,
#   73,
#   70,
#   73,
#   61,
#   63,
#   65,
#   66,
#   60,
#   74,
#   79,
#   80,
#   80],
#  'Placement_score': [80,
#   80,
#   98,
#   100,
#   87,
#   88,
#   90,
#   82,
#   96,
#   97,
#   85,
#   80,
#   88,
#   94,
#   81,
#   100,
#   79,
#   82,
#   76,
#   77,
#   95,
#   94,
#   79,
#   91,
#   91,
#   82,
#   90,
#   82,
#   85,
#   82,
#   88,
#   89,
#   82,
#   81,
#   83,
#   100,
#   98,
#   92,
#   89,
#   95,
#   75,
#   82,
#   91,
#   75,
#   84,
#   85,
#   96,
#   94,
#   85,
#   100,
#   79,
#   77,
#   82,
#   100,
#   91,
#   79,
#   77,
#   91,
#   98,
#   85,
#   87,
#   78,
#   76,
#   97,
#   94,
#   78,
#   96,
#   82,
#   93,
#   95,
#   98,
#   97,
#   81,
#   86,
#   92,
#   99,
#   85,
#   99,
#   78,
#   98,
#   82,
#   83,
#   94,
#   95,
#   76,
#   99,
#   100,
#   80,
#   89,
#   88,
#   89,
#   94,
#   76,
#   95,
#   78,
#   100,
#   99,
#   92,
#   87,
#   96,
#   96,
#   78,
#   96,
#   91,
#   94,
#   86,
#   84,
#   83,
#   94,
#   77,
#   79,
#   82,
#   88,
#   90,
#   83,
#   92,
#   90,
#   79,
#   90,
#   98,
#   97,
#   99,
#   76,
#   97,
#   87,
#   75,
#   85,
#   86,
#   99,
#   86,
#   79,
#   94,
#   77,
#   81,
#   97,
#   79,
#   75,
#   95,
#   98,
#   93,
#   75,
#   75,
#   82,
#   100,
#   96,
#   98,
#   99,
#   81,
#   91,
#   87,
#   82,
#   79,
#   100,
#   87,
#   94,
#   98,
#   79,
#   84,
#   79,
#   85,
#   100,
#   78,
#   87,
#   75,
#   81,
#   94,
#   97,
#   83,
#   96,
#   94,
#   88,
#   78,
#   83,
#   89,
#   96,
#   80,
#   85,
#   87,
#   82,
#   94,
#   96,
#   81,
#   93,
#   89,
#   88,
#   77,
#   75,
#   80,
#   92,
#   84,
#   91,
#   89,
#   99,
#   87,
#   97,
#   76,
#   76,
#   84,
#   78,
#   92,
#   97,
#   95,
#   99,
#   89,
#   99,
#   75,
#   83,
#   76,
#   85,
#   76,
#   95,
#   81,
#   98,
#   85,
#   83,
#   95,
#   100,
#   94,
#   89,
#   86,
#   87,
#   82,
#   75,
#   93,
#   96,
#   82,
#   93,
#   81,
#   89,
#   95,
#   75,
#   97,
#   100,
#   92,
#   79,
#   94,
#   84,
#   82,
#   84,
#   85,
#   97,
#   89,
#   83,
#   84,
#   86,
#   79,
#   78,
#   100,
#   94,
#   98,
#   100,
#   86,
#   91,
#   82,
#   79,
#   95,
#   94,
#   88,
#   83,
#   78,
#   94,
#   85,
#   89,
#   90,
#   83,
#   87,
#   80,
#   87,
#   97,
#   82,
#   84,
#   91,
#   78,
#   88,
#   99,
#   79,
#   77,
#   78,
#   83,
#   82,
#   77,
#   87,
#   90,
#   91,
#   79,
#   94,
#   78,
#   99,
#   100,
#   98,
#   85,
#   81,
#   93,
#   99,
#   76,
#   85,
#   96,
#   81,
#   76,
#   97,
#   92,
#   85,
#   100,
#   78,
#   88,
#   82,
#   94,
#   97,
#   100,
#   88,
#   90,
#   95,
#   93,
#   92,
#   84,
#   76,
#   91,
#   85,
#   75,
#   95,
#   81,
#   90,
#   85,
#   79,
#   89,
#   81,
#   80,
#   93,
#   84,
#   98,
#   95,
#   86,
#   77,
#   76,
#   100,
#   82,
#   77,
#   83,
#   99,
#   78,
#   81,
#   87,
#   91,
#   87,
#   93,
#   98,
#   85,
#   79,
#   82,
#   89,
#   86,
#   88,
#   78,
#   95,
#   96,
#   88,
#   75,
#   79,
#   78,
#   79,
#   84,
#   81,
#   92,
#   79,
#   99,
#   92,
#   75,
#   81,
#   95,
#   82,
#   80,
#   77,
#   86,
#   94,
#   90,
#   77,
#   89,
#   85,
#   93,
#   98,
#   90,
#   82,
#   83,
#   81,
#   78,
#   77,
#   82,
#   78,
#   98,
#   96,
#   80,
#   85,
#   78,
#   94,
#   75,
#   76,
#   84,
#   85,
#   75,
#   95],
#  'Club_Join_Date': ['2021',
#   '2018',
#   '2018',
#   '2018',
#   '2019',
#   '2019',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2021',
#   '2021',
#   '2021',
#   '2021',
#   '2020',
#   '2021',
#   '2019',
#   '2020',
#   '2019',
#   '2018',
#   '2021',
#   '2018',
#   '2021',
#   '2019',
#   '2020',
#   '2019',
#   '2020',
#   '2019',
#   '2021',
#   '2018',
#   '2019',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2018',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2021',
#   '2019',
#   '2018',
#   '2020',
#   '2018',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2019',
#   '2018',
#   '2019',
#   '2018',
#   '2021',
#   '2019',
#   '2019',
#   '2018',
#   '2020',
#   '2018',
#   '2020',
#   '2020',
#   '2019',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2019',
#   '2018',
#   '2020',
#   '2020',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2020',
#   '2021',
#   '2019',
#   '2019',
#   '2019',
#   '2021',
#   '2020',
#   '2020',
#   '2019',
#   '2019',
#   '2020',
#   '2018',
#   '2021',
#   '2018',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2021',
#   '2019',
#   '2018',
#   '2021',
#   '2021',
#   '2018',
#   '2019',
#   '2018',
#   '2020',
#   '2021',
#   '2020',
#   '2018',
#   '2021',
#   '2021',
#   '2019',
#   '2020',
#   '2018',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2020',
#   '2021',
#   '2019',
#   '2019',
#   '2020',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2020',
#   '2020',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2019',
#   '2020',
#   '2021',
#   '2020',
#   '2021',
#   '2020',
#   '2019',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2021',
#   '2019',
#   '2019',
#   '2019',
#   '2021',
#   '2019',
#   '2020',
#   '2018',
#   '2019',
#   '2018',
#   '2021',
#   '2020',
#   '2020',
#   '2021',
#   '2019',
#   '2020',
#   '2020',
#   '2018',
#   '2020',
#   '2018',
#   '2020',
#   '2018',
#   '2020',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2019',
#   '2021',
#   '2019',
#   '2020',
#   '2020',
#   '2020',
#   '2021',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2021',
#   '2018',
#   '2018',
#   '2020',
#   '2021',
#   '2019',
#   '2018',
#   '2021',
#   '2021',
#   '2018',
#   '2020',
#   '2021',
#   '2019',
#   '2021',
#   '2019',
#   '2018',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2020',
#   '2018',
#   '2019',
#   '2018',
#   '2020',
#   '2021',
#   '2020',
#   '2019',
#   '2019',
#   '2018',
#   '2018',
#   '2018',
#   '2018',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2019',
#   '2019',
#   '2018',
#   '2020',
#   '2021',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2020',
#   '2019',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2018',
#   '2019',
#   '2019',
#   '2018',
#   '2020',
#   '2019',
#   '2020',
#   '2020',
#   '2021',
#   '2018',
#   '2018',
#   '2018',
#   '2019',
#   '2018',
#   '2021',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2021',
#   '2019',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2021',
#   '2019',
#   '2018',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2021',
#   '2018',
#   '2018',
#   '2019',
#   '2020',
#   '2020',
#   '2021',
#   '2019',
#   '2021',
#   '2020',
#   '2020',
#   '2018',
#   '2018',
#   '2019',
#   '2018',
#   '2020',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2020',
#   '2019',
#   '2019',
#   '2019',
#   '2021',
#   '2021',
#   '2018',
#   '2021',
#   '2019',
#   '2020',
#   '2021',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2019',
#   '2018',
#   '2021',
#   '2018',
#   '2020',
#   '2021',
#   '2019',
#   '2018',
#   '2018',
#   '2020',
#   '2019',
#   '2021',
#   '2019',
#   '2021',
#   '2019',
#   '2019',
#   '2018',
#   '2021',
#   '2021',
#   '2019',
#   '2021',
#   '2021',
#   '2021',
#   '2020',
#   '2018',
#   '2020',
#   '2020',
#   '2018',
#   '2020',
#   '2021',
#   '2019',
#   '2018',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2021',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2020',
#   '2020',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2018',
#   '2018',
#   '2019',
#   '2019',
#   '2021',
#   '2019',
#   '2018',
#   '2019',
#   '2018',
#   '2021',
#   '2021',
#   '2021',
#   '2021',
#   '2019',
#   '2020',
#   '2020',
#   '2018',
#   '2021',
#   '2020',
#   '2021']}

# %%
dataFrame = pd.DataFrame(df)

# %%
dataFrame.to_csv("Student_performance.csv")

# %%
dataFrame.shape
# Out:
# (400, 5)

# %%
dataFrame.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 0        71.0           81.0             66               80           2021
# 1         NaN           79.0             60               80           2018
# 2        69.0           77.0             76               98           2018
# 3         NaN           92.0             66              100           2018
# 4         NaN           94.0             76               87           2019

# %%
dataFrame.tail()
# Out:
#      Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 395        73.0           79.0             60               76           2020
# 396        72.0           95.0             74               84           2018
# 397        76.0           90.0             79               85           2021
# 398        68.0           85.0             80               75           2020
# 399        64.0           83.0             80               95           2021

# %%
dataFrame.sample(5)
# Out:
#      Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 100        69.0           95.0             68               96           2018
# 94          NaN           84.0             75               78           2020
# 216        79.0           87.0             70              100           2021
# 109        73.0            NaN             79               77           2018
# 139        65.0           78.0             75               93           2019

# %%
dataFrame.columns
# Out:
# Index(['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_Join_Date'],
#       dtype='object')

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_score       320 non-null    float64
#  1   Reading_score    360 non-null    float64
#  2   Writing_score    400 non-null    int64
#  3   Placement_score  400 non-null    int64
#  4   Club_Join_Date   400 non-null    object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 15.8+ KB

# %%
dataFrame.dtypes
# Out:
# Math_score         float64
# Reading_score      float64
# Writing_score        int64
# Placement_score      int64
# Club_Join_Date      object
# dtype: object

# %%
dataFrame['Club_Join_Date']=dataFrame['Club_Join_Date'].astype("datetime64[ns]")

# %%
dataFrame.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score
# count  320.000000     360.000000      400.00000       400.000000  \
# mean    70.143750      85.169444       70.23500        87.285000
# min     60.000000      75.000000       60.00000        75.000000
# 25%     65.000000      80.000000       65.00000        81.000000
# 50%     71.000000      85.000000       70.00000        87.000000
# 75%     76.000000      90.000000       75.00000        94.000000
# max     80.000000      95.000000       80.00000       100.000000
# std      6.070481       6.013602        5.91373         7.637382
#
#                       Club_Join_Date
# count                            400
# mean   2019-06-14 11:56:23.999999744
# min              2018-01-01 00:00:00
# 25%              2018-01-01 00:00:00
# 50%              2019-01-01 00:00:00
# 75%              2020-01-01 00:00:00
# max              2021-01-01 00:00:00
# std                              NaN

# %%
dataFrame.dtypes
# Out:
# Math_score                float64
# Reading_score             float64
# Writing_score               int64
# Placement_score             int64
# Club_Join_Date     datetime64[ns]
# dtype: object

# %%
dataFrame.iloc[:,0:4].head(5)
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score
# 0        71.0           81.0             66               80
# 1         NaN           79.0             60               80
# 2        69.0           77.0             76               98
# 3         NaN           92.0             66              100
# 4         NaN           94.0             76               87

# %%
dataFrame.loc[:,["Placement_score","Club_Join_Date"]].head(5)
# Out:
#    Placement_score Club_Join_Date
# 0               80     2021-01-01
# 1               80     2018-01-01
# 2               98     2018-01-01
# 3              100     2018-01-01
# 4               87     2019-01-01

# %%
dataFrame['Club_Join_Date'].value_counts()
# Out:
# Club_Join_Date
# 2018-01-01    112
# 2021-01-01     99
# 2019-01-01     95
# 2020-01-01     94
# Name: count, dtype: int64

# %%
dataFrame.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
dataFrame.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score
# count  320.000000     360.000000      400.00000       400.000000  \
# mean    70.143750      85.169444       70.23500        87.285000
# min     60.000000      75.000000       60.00000        75.000000
# 25%     65.000000      80.000000       65.00000        81.000000
# 50%     71.000000      85.000000       70.00000        87.000000
# 75%     76.000000      90.000000       75.00000        94.000000
# max     80.000000      95.000000       80.00000       100.000000
# std      6.070481       6.013602        5.91373         7.637382
#
#                       Club_Join_Date
# count                            400
# mean   2019-06-14 11:56:23.999999744
# min              2018-01-01 00:00:00
# 25%              2018-01-01 00:00:00
# 50%              2019-01-01 00:00:00
# 75%              2020-01-01 00:00:00
# max              2021-01-01 00:00:00
# std                              NaN

# %%
dataFrame.duplicated().sum()
# Out:
# 0

# %%
dataFrame.nunique()
# Out:
# Math_score         21
# Reading_score      21
# Writing_score      21
# Placement_score    26
# Club_Join_Date      4
# dtype: int64

# %%
dataFrame.isnull().sum()
# Out:
# Math_score         80
# Reading_score      40
# Writing_score       0
# Placement_score     0
# Club_Join_Date      0
# dtype: int64

# %%
dataFrame['Math_score'].mean()
# Out:
# 70.14375

# %%
dataFrame['Math_score'].fillna(dataFrame['Math_score'].mean(), inplace=True)
dataFrame['Reading_score'].fillna(dataFrame['Reading_score'].mean(), inplace=True)

# %%
dataFrame.isnull().sum()
# Out:
# Math_score         0
# Reading_score      0
# Writing_score      0
# Placement_score    0
# Club_Join_Date     0
# dtype: int64

# %%
pd.get_dummies(dataFrame,columns=['Club_Join_Date'],).head()  # label Encoding
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score
# 0    71.00000           81.0             66               80  \
# 1    70.14375           79.0             60               80
# 2    69.00000           77.0             76               98
# 3    70.14375           92.0             66              100
# 4    70.14375           94.0             76               87
#
#    Club_Join_Date_2018-01-01 00:00:00  Club_Join_Date_2019-01-01 00:00:00
# 0                               False                               False  \
# 1                                True                               False
# 2                                True                               False
# 3                                True                               False
# 4                               False                                True
#
#    Club_Join_Date_2020-01-01 00:00:00  Club_Join_Date_2021-01-01 00:00:00
# 0                               False                                True
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                               False                               False

# %%
# Generating outliers
for i in [random.randint(0, 400) for _ in range(8)]:
    
    dataFrame['Math_score'][i] = random.randint(-10, 20)

# %%
dataFrame['Math_score'].describe()
# Out:
# count    400.000000
# mean      68.741250
# std       10.640971
# min      -10.000000
# 25%       66.000000
# 50%       70.143750
# 75%       73.250000
# max       80.000000
# Name: Math_score, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])
# Out:
# <Axes: >

# %%
percentile25 = dataFrame['Math_score'].quantile(0.25)
percentile75 = dataFrame['Math_score'].quantile(0.75)

# %%
percentile25
# Out:
# 66.0

# %%
percentile75
# Out:
# 73.25

# %%
iqr = percentile75 - percentile25
iqr
# Out:
# 7.25

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 84.125
# Lower limit 55.125

# %%
dataFrame[dataFrame['Math_score'] > upper_limit]
# Out:
# Empty DataFrame
# Columns: [Math_score, Reading_score, Writing_score, Placement_score, Club_Join_Date]
# Index: []

# %%
dataFrame[dataFrame['Math_score'] < lower_limit]
# Out:
#      Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 51         -6.0      79.000000             60               77     2019-01-01
# 72         -7.0      88.000000             63               81     2020-01-01
# 80         18.0      92.000000             73               82     2020-01-01
# 149         8.0      84.000000             60               87     2018-01-01
# 182       -10.0      93.000000             65               93     2020-01-01
# 216         7.0      87.000000             70              100     2021-01-01
# 309        16.0      85.169444             73               88     2018-01-01
# 371        16.0      84.000000             66               77     2021-01-01

# %%
new_dataFrame = dataFrame[dataFrame['Math_score'] > lower_limit]
new_dataFrame.shape
# Out:
# (392, 5)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])

plt.subplot(2,2,3)
sns.distplot(new_dataFrame['Math_score'])

plt.subplot(2,2,4)
sns.boxplot(new_dataFrame['Math_score'])

plt.show()

# %%
new_df_cap = dataFrame.copy()

new_df_cap['Math_score'] = np.where(
    new_df_cap['Math_score'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['Math_score'] < lower_limit,
        lower_limit,
        new_df_cap['Math_score']
    )
)

# %%
new_df_cap.shape
# Out:
# (400, 5)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])

plt.subplot(2,2,3)
sns.distplot(new_df_cap['Math_score'])

plt.subplot(2,2,4)
sns.boxplot(new_df_cap['Math_score'])

plt.show()
